# %%
import pandas as pd

# %%
df = pd.read_csv(r'Desktop\ML_DA\Pandas\fifa21_raw_data.csv', index_col = 'LongName', low_memory = True)

# %%
pd.set_option('display.max_columns', 80)

# %%
df
# Out:
#                                                                       photoUrl  \
# LongName
# Lionel Messi                  https://cdn.sofifa.com/players/158/023/21_60.png
# C. Ronaldo dos Santos Aveiro  https://cdn.sofifa.com/players/020/801/21_60.png
# Jan Oblak                     https://cdn.sofifa.com/players/200/389/21_60.png
# Kevin De Bruyne               https://cdn.sofifa.com/players/192/985/21_60.png
# Neymar da Silva Santos Jr.    https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                                        ...
# Mengxuan Zhang                https://cdn.sofifa.com/players/257/710/21_60.png
# Vani Da Silva                 https://cdn.sofifa.com/players/258/736/21_60.png
# Ao Xia                        https://cdn.sofifa.com/players/247/223/21_60.png
# Ben Hough                     https://cdn.sofifa.com/players/258/760/21_60.png
# Mateo Flores                  https://cdn.sofifa.com/players/255/958/21_60.png
#
# ...

# %%
df.rename(columns={'Height': 'Height(Inches)'})
# Out:
#                                                                       photoUrl  \
# LongName
# Lionel Messi                  https://cdn.sofifa.com/players/158/023/21_60.png
# C. Ronaldo dos Santos Aveiro  https://cdn.sofifa.com/players/020/801/21_60.png
# Jan Oblak                     https://cdn.sofifa.com/players/200/389/21_60.png
# Kevin De Bruyne               https://cdn.sofifa.com/players/192/985/21_60.png
# Neymar da Silva Santos Jr.    https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                                        ...
# Mengxuan Zhang                https://cdn.sofifa.com/players/257/710/21_60.png
# Vani Da Silva                 https://cdn.sofifa.com/players/258/736/21_60.png
# Ao Xia                        https://cdn.sofifa.com/players/247/223/21_60.png
# Ben Hough                     https://cdn.sofifa.com/players/258/760/21_60.png
# Mateo Flores                  https://cdn.sofifa.com/players/255/958/21_60.png
#
# ...

# %%
df.rename(columns={'Weight': 'Weight(lbs)'})
# Out:
#                                                                       photoUrl  \
# LongName
# Lionel Messi                  https://cdn.sofifa.com/players/158/023/21_60.png
# C. Ronaldo dos Santos Aveiro  https://cdn.sofifa.com/players/020/801/21_60.png
# Jan Oblak                     https://cdn.sofifa.com/players/200/389/21_60.png
# Kevin De Bruyne               https://cdn.sofifa.com/players/192/985/21_60.png
# Neymar da Silva Santos Jr.    https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                                        ...
# Mengxuan Zhang                https://cdn.sofifa.com/players/257/710/21_60.png
# Vani Da Silva                 https://cdn.sofifa.com/players/258/736/21_60.png
# Ao Xia                        https://cdn.sofifa.com/players/247/223/21_60.png
# Ben Hough                     https://cdn.sofifa.com/players/258/760/21_60.png
# Mateo Flores                  https://cdn.sofifa.com/players/255/958/21_60.png
#
# ...

# %%
df['Height(Inches)']= df['Height(Inches)'].str.replace('"', '')

# %%
df[['Feet', 'Inches']]= df['Height(Inches)'].str.split("'", expand=True)

# %%
df['Height(Inches)'] = df['Inches'] + (df['Feet']*12)

# %%
df[['Feet', 'Inches']]= df[['Feet', 'Inches']].astype(int)

# %%
df[['Feet', 'Inches']].dtypes
# Out:
# Feet      int32
# Inches    int32
# dtype: object

# %%
df['Height_inches'] = (df['Feet']*12) + df['Inches']

# %%
df['Weight'] = df['Weight'].str.replace('lbs', '')

# %%
df['Weight']= df['Weight'].astype(int)

# %%
df[['Date_Joined', 'Year_Joined']] = df['Joined'].str.split(',' , expand= True)

# %%
df[['Month_Joined', 'Day_Joined']] = df['Date_Joined'].str.split(' ' , expand= True)

# %%
df
# Out:
#                                                                       photoUrl  \
# LongName
# Lionel Messi                  https://cdn.sofifa.com/players/158/023/21_60.png
# C. Ronaldo dos Santos Aveiro  https://cdn.sofifa.com/players/020/801/21_60.png
# Jan Oblak                     https://cdn.sofifa.com/players/200/389/21_60.png
# Kevin De Bruyne               https://cdn.sofifa.com/players/192/985/21_60.png
# Neymar da Silva Santos Jr.    https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                                        ...
# Mengxuan Zhang                https://cdn.sofifa.com/players/257/710/21_60.png
# Vani Da Silva                 https://cdn.sofifa.com/players/258/736/21_60.png
# Ao Xia                        https://cdn.sofifa.com/players/247/223/21_60.png
# Ben Hough                     https://cdn.sofifa.com/players/258/760/21_60.png
# Mateo Flores                  https://cdn.sofifa.com/players/255/958/21_60.png
#
# ...

# %%
df.drop(columns=['Height(Inches)','Feet', 'Inches', 'Date_Joined'])
# Out:
#                                                                       photoUrl  \
# LongName
# Lionel Messi                  https://cdn.sofifa.com/players/158/023/21_60.png
# C. Ronaldo dos Santos Aveiro  https://cdn.sofifa.com/players/020/801/21_60.png
# Jan Oblak                     https://cdn.sofifa.com/players/200/389/21_60.png
# Kevin De Bruyne               https://cdn.sofifa.com/players/192/985/21_60.png
# Neymar da Silva Santos Jr.    https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                                        ...
# Mengxuan Zhang                https://cdn.sofifa.com/players/257/710/21_60.png
# Vani Da Silva                 https://cdn.sofifa.com/players/258/736/21_60.png
# Ao Xia                        https://cdn.sofifa.com/players/247/223/21_60.png
# Ben Hough                     https://cdn.sofifa.com/players/258/760/21_60.png
# Mateo Flores                  https://cdn.sofifa.com/players/255/958/21_60.png
#
# ...

# %%
df['Wages'] = df['Wage'].str.replace('€', '')

# %%
df['Wages_Multiplier'] = df['Wages_Multiplier'].fillna(1)

# %%
df['Wages_Multiplier']= df['Wages'].str.extract(r'(\D)$')

# %%
df['Wages'] = df['Wages'].str.replace('K', '')

# %%
df
# Out:
#                                                                       photoUrl  \
# LongName
# Lionel Messi                  https://cdn.sofifa.com/players/158/023/21_60.png
# C. Ronaldo dos Santos Aveiro  https://cdn.sofifa.com/players/020/801/21_60.png
# Jan Oblak                     https://cdn.sofifa.com/players/200/389/21_60.png
# Kevin De Bruyne               https://cdn.sofifa.com/players/192/985/21_60.png
# Neymar da Silva Santos Jr.    https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                                        ...
# Mengxuan Zhang                https://cdn.sofifa.com/players/257/710/21_60.png
# Vani Da Silva                 https://cdn.sofifa.com/players/258/736/21_60.png
# Ao Xia                        https://cdn.sofifa.com/players/247/223/21_60.png
# Ben Hough                     https://cdn.sofifa.com/players/258/760/21_60.png
# Mateo Flores                  https://cdn.sofifa.com/players/255/958/21_60.png
#
# ...

# %%
df['Wages_Multiplier2'] = df['Wages_Multiplier'].copy()

# %%
df['Wages_Multiplier2'] = df['Wages_Multiplier2'].str.replace('K', '1000')

# %%
df['Wages_Multiplier2'] = df['Wages_Multiplier2'].fillna(1)

# %%
df['Wages_Multiplier2'] = df['Wages_Multiplier2'].astype(float)

# %%
df['Wages_Multiplier2'].dtype
# Out:
# dtype('float64')

# %%
df['Wages']=df['Wages'].astype(float)

# %%
df['Final_Wage'] = (df['Wages'] * df['Wages_Multiplier2']).astype(int)

# %%
df
# Out:
#                                                                       photoUrl  \
# LongName
# Lionel Messi                  https://cdn.sofifa.com/players/158/023/21_60.png
# C. Ronaldo dos Santos Aveiro  https://cdn.sofifa.com/players/020/801/21_60.png
# Jan Oblak                     https://cdn.sofifa.com/players/200/389/21_60.png
# Kevin De Bruyne               https://cdn.sofifa.com/players/192/985/21_60.png
# Neymar da Silva Santos Jr.    https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                                        ...
# Mengxuan Zhang                https://cdn.sofifa.com/players/257/710/21_60.png
# Vani Da Silva                 https://cdn.sofifa.com/players/258/736/21_60.png
# Ao Xia                        https://cdn.sofifa.com/players/247/223/21_60.png
# Ben Hough                     https://cdn.sofifa.com/players/258/760/21_60.png
# Mateo Flores                  https://cdn.sofifa.com/players/255/958/21_60.png
#
# ...

# %%
df['Value'] = df['Value'].str.replace('€', '')
df['Value_Multiplier']= df['Value'].str.extract(r'(\D)$')

# %%
df['Value_Multiplier2'] = df['Value_Multiplier'].str.replace('M', '1000000').str.replace('K', '1000')

# %%
df['Value_Multiplier2'].fillna(1)
# Out:
# LongName
# Lionel Messi                    1000000
# C. Ronaldo dos Santos Aveiro    1000000
# Jan Oblak                       1000000
# Kevin De Bruyne                 1000000
# Neymar da Silva Santos Jr.      1000000
#                                  ...
# Mengxuan Zhang                     1000
# Vani Da Silva                      1000
# Ao Xia                             1000
# Ben Hough                          1000
# Mateo Flores                       1000
# Name: Value_Multiplier2, Length: 18979, dtype: object

# %%
df.drop(columns= ('Values'))
# Out:
#                                                                       photoUrl  \
# LongName
# Lionel Messi                  https://cdn.sofifa.com/players/158/023/21_60.png
# C. Ronaldo dos Santos Aveiro  https://cdn.sofifa.com/players/020/801/21_60.png
# Jan Oblak                     https://cdn.sofifa.com/players/200/389/21_60.png
# Kevin De Bruyne               https://cdn.sofifa.com/players/192/985/21_60.png
# Neymar da Silva Santos Jr.    https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                                        ...
# Mengxuan Zhang                https://cdn.sofifa.com/players/257/710/21_60.png
# Vani Da Silva                 https://cdn.sofifa.com/players/258/736/21_60.png
# Ao Xia                        https://cdn.sofifa.com/players/247/223/21_60.png
# Ben Hough                     https://cdn.sofifa.com/players/258/760/21_60.png
# Mateo Flores                  https://cdn.sofifa.com/players/255/958/21_60.png
#
# ...

# %%
df['Values'] = df['Value'].str.replace('M', '').str.replace('K', '')

# %%
df.drop(columns = ('Values'), inplace = True)

# %%
df.columns
# Out:
# Index([                     'photoUrl',                     'playerUrl',
#                          'Nationality',                     'Positions',
#                                 'Name',                           'Age',
#                                 '↓OVA',                           'POT',
#                      'Team & Contract',                            'ID',
#                       'Height(Inches)',                        'Weight',
#                                 'foot',                           'BOV',
#                                   'BP',                        'Growth',
#                               'Joined',                 'Loan Date End',
#                                'Value',                          'Wage',
#                       'Release Clause',                     'Attacking',
#                             'Crossing',                     'Finishing',
#                     'Heading Accuracy',                 'Short Passing',
# ...

# %%
df.drop(columns = ('Value_Multiplier2', 'Values'), inplace = True)

# %%
df
# Out:
#                                                                       photoUrl  \
# LongName
# Lionel Messi                  https://cdn.sofifa.com/players/158/023/21_60.png
# C. Ronaldo dos Santos Aveiro  https://cdn.sofifa.com/players/020/801/21_60.png
# Jan Oblak                     https://cdn.sofifa.com/players/200/389/21_60.png
# Kevin De Bruyne               https://cdn.sofifa.com/players/192/985/21_60.png
# Neymar da Silva Santos Jr.    https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                                        ...
# Mengxuan Zhang                https://cdn.sofifa.com/players/257/710/21_60.png
# Vani Da Silva                 https://cdn.sofifa.com/players/258/736/21_60.png
# Ao Xia                        https://cdn.sofifa.com/players/247/223/21_60.png
# Ben Hough                     https://cdn.sofifa.com/players/258/760/21_60.png
# Mateo Flores                  https://cdn.sofifa.com/players/255/958/21_60.png
#
# ...

# %%
df['Values'] = df['Value'].str.replace('M', '').str.replace('K', '')

# %%
df['Values']=df['Values'].astype(float)

# %%
df['Values'].dtype
# Out:
# dtype('float64')

# %%
df['Value_Multiplier2']=df['Value_Multiplier2'].astype(float)

# %%
df['Final_Value'] = df['Values'] * df['Value_Multiplier2']

# %%
df
# Out:
#                                                                       photoUrl  \
# LongName
# Lionel Messi                  https://cdn.sofifa.com/players/158/023/21_60.png
# C. Ronaldo dos Santos Aveiro  https://cdn.sofifa.com/players/020/801/21_60.png
# Jan Oblak                     https://cdn.sofifa.com/players/200/389/21_60.png
# Kevin De Bruyne               https://cdn.sofifa.com/players/192/985/21_60.png
# Neymar da Silva Santos Jr.    https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                                        ...
# Mengxuan Zhang                https://cdn.sofifa.com/players/257/710/21_60.png
# Vani Da Silva                 https://cdn.sofifa.com/players/258/736/21_60.png
# Ao Xia                        https://cdn.sofifa.com/players/247/223/21_60.png
# Ben Hough                     https://cdn.sofifa.com/players/258/760/21_60.png
# Mateo Flores                  https://cdn.sofifa.com/players/255/958/21_60.png
#
# ...

# %%
df['Release Clauses'] = df['Release Clause'].str.replace('€', '')
df['Release Clauses']= df['Release Clause'].str.extract(r'(\D)$')

# %%
df['Release_Clause2'] = df['Release Clause'].str.replace('€', '').str.replace('M', '').str.replace('K', '')

# %%
df['RC_Multiplier'] = df['Release Clauses'].str.replace('M', '1000000').str.replace('K', '1000')

# %%
df
# Out:
#                                                                       photoUrl  \
# LongName
# Lionel Messi                  https://cdn.sofifa.com/players/158/023/21_60.png
# C. Ronaldo dos Santos Aveiro  https://cdn.sofifa.com/players/020/801/21_60.png
# Jan Oblak                     https://cdn.sofifa.com/players/200/389/21_60.png
# Kevin De Bruyne               https://cdn.sofifa.com/players/192/985/21_60.png
# Neymar da Silva Santos Jr.    https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                                        ...
# Mengxuan Zhang                https://cdn.sofifa.com/players/257/710/21_60.png
# Vani Da Silva                 https://cdn.sofifa.com/players/258/736/21_60.png
# Ao Xia                        https://cdn.sofifa.com/players/247/223/21_60.png
# Ben Hough                     https://cdn.sofifa.com/players/258/760/21_60.png
# Mateo Flores                  https://cdn.sofifa.com/players/255/958/21_60.png
#
# ...

# %%
df['Release_Clause2']=df['Release_Clause2'].astype(float)

# %%
df['RC_Multiplier']=df['RC_Multiplier'].astype(float)

# %%
df['Final_RC'] = df['Release_Clause2'] * df['RC_Multiplier']

# %%
df
# Out:
#                                                                       photoUrl  \
# LongName
# Lionel Messi                  https://cdn.sofifa.com/players/158/023/21_60.png
# C. Ronaldo dos Santos Aveiro  https://cdn.sofifa.com/players/020/801/21_60.png
# Jan Oblak                     https://cdn.sofifa.com/players/200/389/21_60.png
# Kevin De Bruyne               https://cdn.sofifa.com/players/192/985/21_60.png
# Neymar da Silva Santos Jr.    https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                                        ...
# Mengxuan Zhang                https://cdn.sofifa.com/players/257/710/21_60.png
# Vani Da Silva                 https://cdn.sofifa.com/players/258/736/21_60.png
# Ao Xia                        https://cdn.sofifa.com/players/247/223/21_60.png
# Ben Hough                     https://cdn.sofifa.com/players/258/760/21_60.png
# Mateo Flores                  https://cdn.sofifa.com/players/255/958/21_60.png
#
# ...

# %%
df['Hits'] = df['Hits'].str.replace('\n', '')

# %%
df
# Out:
#                                                                       photoUrl  \
# LongName
# Lionel Messi                  https://cdn.sofifa.com/players/158/023/21_60.png
# C. Ronaldo dos Santos Aveiro  https://cdn.sofifa.com/players/020/801/21_60.png
# Jan Oblak                     https://cdn.sofifa.com/players/200/389/21_60.png
# Kevin De Bruyne               https://cdn.sofifa.com/players/192/985/21_60.png
# Neymar da Silva Santos Jr.    https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                                        ...
# Mengxuan Zhang                https://cdn.sofifa.com/players/257/710/21_60.png
# Vani Da Silva                 https://cdn.sofifa.com/players/258/736/21_60.png
# Ao Xia                        https://cdn.sofifa.com/players/247/223/21_60.png
# Ben Hough                     https://cdn.sofifa.com/players/258/760/21_60.png
# Mateo Flores                  https://cdn.sofifa.com/players/255/958/21_60.png
#
# ...

# %%
df['Team & Contract'] = df['Team & Contract'].str.replace('\n', '')

# %%
df
# Out:
#                                                                       photoUrl  \
# LongName
# Lionel Messi                  https://cdn.sofifa.com/players/158/023/21_60.png
# C. Ronaldo dos Santos Aveiro  https://cdn.sofifa.com/players/020/801/21_60.png
# Jan Oblak                     https://cdn.sofifa.com/players/200/389/21_60.png
# Kevin De Bruyne               https://cdn.sofifa.com/players/192/985/21_60.png
# Neymar da Silva Santos Jr.    https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                                        ...
# Mengxuan Zhang                https://cdn.sofifa.com/players/257/710/21_60.png
# Vani Da Silva                 https://cdn.sofifa.com/players/258/736/21_60.png
# Ao Xia                        https://cdn.sofifa.com/players/247/223/21_60.png
# Ben Hough                     https://cdn.sofifa.com/players/258/760/21_60.png
# Mateo Flores                  https://cdn.sofifa.com/players/255/958/21_60.png
#
# ...

# %%
df.drop(columns = ('Height(Inches)'))
# Out:
#                                                                       photoUrl  \
# LongName
# Lionel Messi                  https://cdn.sofifa.com/players/158/023/21_60.png
# C. Ronaldo dos Santos Aveiro  https://cdn.sofifa.com/players/020/801/21_60.png
# Jan Oblak                     https://cdn.sofifa.com/players/200/389/21_60.png
# Kevin De Bruyne               https://cdn.sofifa.com/players/192/985/21_60.png
# Neymar da Silva Santos Jr.    https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                                        ...
# Mengxuan Zhang                https://cdn.sofifa.com/players/257/710/21_60.png
# Vani Da Silva                 https://cdn.sofifa.com/players/258/736/21_60.png
# Ao Xia                        https://cdn.sofifa.com/players/247/223/21_60.png
# Ben Hough                     https://cdn.sofifa.com/players/258/760/21_60.png
# Mateo Flores                  https://cdn.sofifa.com/players/255/958/21_60.png
#
# ...

# %%
df.rename(columns = {'Weight' : "Weight(lbs)"}, inplace = True)
